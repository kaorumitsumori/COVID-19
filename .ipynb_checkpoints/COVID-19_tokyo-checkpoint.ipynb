# %% [markdown]
# ## Read json file from Tokyo COVID-19 Task Force website

# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt

tokyo_data = pd.read_json('/Users/kaorumitsumori/Desktop/COVID-19/data_tokyo20200315.json')
tokyo_data["patients"]["data"]
# Out:
# [{'リリース日': '2020-01-24T08:00:00.000Z',
#   '曜日': 43854,
#   '居住地': '湖北省武漢市',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-01-24'},
#  {'リリース日': '2020-01-25T08:00:00.000Z',
#   '曜日': 43855,
#   '居住地': '湖北省武漢市',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-01-25'},
#  {'リリース日': '2020-01-30T08:00:00.000Z',
#   '曜日': 43860,
#   '居住地': '湖南省長沙市',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-01-30'},
#  {'リリース日': '2020-02-13T08:00:00.000Z',
#   '曜日': 43874,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-13'},
#  {'リリース日': '2020-02-14T08:00:00.000Z',
#   '曜日': 43875,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-14'},
#  {'リリース日': '2020-02-14T08:00:00.000Z',
#   '曜日': 43875,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-14'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-15T08:00:00.000Z',
#   '曜日': 43876,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-15'},
#  {'リリース日': '2020-02-16T08:00:00.000Z',
#   '曜日': 43877,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-16'},
#  {'リリース日': '2020-02-16T08:00:00.000Z',
#   '曜日': 43877,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-16'},
#  {'リリース日': '2020-02-16T08:00:00.000Z',
#   '曜日': 43877,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-16'},
#  {'リリース日': '2020-02-16T08:00:00.000Z',
#   '曜日': 43877,
#   '居住地': '埼玉県',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-16'},
#  {'リリース日': '2020-02-16T08:00:00.000Z',
#   '曜日': 43877,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-16'},
#  {'リリース日': '2020-02-18T08:00:00.000Z',
#   '曜日': 43879,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-18'},
#  {'リリース日': '2020-02-18T08:00:00.000Z',
#   '曜日': 43879,
#   '居住地': '都内',
#   '年代': '20代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-02-18'},
#  {'リリース日': '2020-02-18T08:00:00.000Z',
#   '曜日': 43879,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-18'},
#  {'リリース日': '2020-02-19T08:00:00.000Z',
#   '曜日': 43880,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-19'},
#  {'リリース日': '2020-02-19T08:00:00.000Z',
#   '曜日': 43880,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-19'},
#  {'リリース日': '2020-02-19T08:00:00.000Z',
#   '曜日': 43880,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-02-19'},
#  {'リリース日': '2020-02-21T08:00:00.000Z',
#   '曜日': 43882,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-02-21'},
#  {'リリース日': '2020-02-21T08:00:00.000Z',
#   '曜日': 43882,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-21'},
#  {'リリース日': '2020-02-21T08:00:00.000Z',
#   '曜日': 43882,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-02-21'},
#  {'リリース日': '2020-02-22T08:00:00.000Z',
#   '曜日': 43883,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-22'},
#  {'リリース日': '2020-02-24T08:00:00.000Z',
#   '曜日': 43885,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-24'},
#  {'リリース日': '2020-02-24T08:00:00.000Z',
#   '曜日': 43885,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-24'},
#  {'リリース日': '2020-02-24T08:00:00.000Z',
#   '曜日': 43885,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-24'},
#  {'リリース日': '2020-02-26T08:00:00.000Z',
#   '曜日': 43887,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-26'},
#  {'リリース日': '2020-02-26T08:00:00.000Z',
#   '曜日': 43887,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-26'},
#  {'リリース日': '2020-02-26T08:00:00.000Z',
#   '曜日': 43887,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-02-26'},
#  {'リリース日': '2020-02-27T08:00:00.000Z',
#   '曜日': 43888,
#   '居住地': '都外',
#   '年代': '60代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-02-27'},
#  {'リリース日': '2020-02-29T08:00:00.000Z',
#   '曜日': 43890,
#   '居住地': '都内',
#   '年代': '20代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-02-29'},
#  {'リリース日': '2020-03-01T08:00:00.000Z',
#   '曜日': 43891,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': '〇',
#   'date': '2020-03-01'},
#  {'リリース日': '2020-03-01T08:00:00.000Z',
#   '曜日': 43891,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-01'},
#  {'リリース日': '2020-03-03T08:00:00.000Z',
#   '曜日': 43893,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-03'},
#  {'リリース日': '2020-03-04T08:00:00.000Z',
#   '曜日': 43894,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-04'},
#  {'リリース日': '2020-03-04T08:00:00.000Z',
#   '曜日': 43894,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-04'},
#  {'リリース日': '2020-03-04T08:00:00.000Z',
#   '曜日': 43894,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-04'},
#  {'リリース日': '2020-03-04T08:00:00.000Z',
#   '曜日': 43894,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-04'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '10歳未満',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '10歳未満',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '20代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '90代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-05T08:00:00.000Z',
#   '曜日': 43895,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-05'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '90代',
#   '性別': '男性',
#   '退院': '〇',
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-06T08:00:00.000Z',
#   '曜日': 43896,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-06'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-07T08:00:00.000Z',
#   '曜日': 43897,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-07'},
#  {'リリース日': '2020-03-10T08:00:00.000Z',
#   '曜日': 43900,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-10'},
#  {'リリース日': '2020-03-10T08:00:00.000Z',
#   '曜日': 43900,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-10'},
#  {'リリース日': '2020-03-10T08:00:00.000Z',
#   '曜日': 43900,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-10'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '80代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-11T08:00:00.000Z',
#   '曜日': 43901,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-11'},
#  {'リリース日': '2020-03-12T08:00:00.000Z',
#   '曜日': 43902,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-12'},
#  {'リリース日': '2020-03-12T08:00:00.000Z',
#   '曜日': 43902,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-12'},
#  {'リリース日': '2020-03-13T08:00:00.000Z',
#   '曜日': 43903,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-13'},
#  {'リリース日': '2020-03-13T08:00:00.000Z',
#   '曜日': 43903,
#   '居住地': '都内',
#   '年代': '70代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-13'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都外',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '女性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都外',
#   '年代': '70代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '30代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '40代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '60代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'},
#  {'リリース日': '2020-03-14T08:00:00.000Z',
#   '曜日': 43904,
#   '居住地': '都内',
#   '年代': '50代',
#   '性別': '男性',
#   '退院': None,
#   'date': '2020-03-14'}]

# %% [markdown]
# ## Convert into DataFrame and quick look

# %%
df_tokyo_data = pd.DataFrame(tokyo_data["patients"]["data"])
df_tokyo_data.head(10)
# Out:
#                       リリース日     曜日     居住地   年代  性別    退院        date
# 0  2020-01-24T08:00:00.000Z  43854  湖北省武漢市  40代  男性     〇  2020-01-24
# 1  2020-01-25T08:00:00.000Z  43855  湖北省武漢市  30代  女性     〇  2020-01-25
# 2  2020-01-30T08:00:00.000Z  43860  湖南省長沙市  30代  女性     〇  2020-01-30
# 3  2020-02-13T08:00:00.000Z  43874      都内  70代  男性  None  2020-02-13
# 4  2020-02-14T08:00:00.000Z  43875      都内  50代  女性     〇  2020-02-14
# 5  2020-02-14T08:00:00.000Z  43875      都内  70代  男性     〇  2020-02-14
# 6  2020-02-15T08:00:00.000Z  43876      都内  80代  男性     〇  2020-02-15
# 7  2020-02-15T08:00:00.000Z  43876      都内  50代  女性     〇  2020-02-15
# 8  2020-02-15T08:00:00.000Z  43876      都内  50代  男性     〇  2020-02-15
# 9  2020-02-15T08:00:00.000Z  43876      都内  70代  男性     〇  2020-02-15

# %%
df_tokyo_data.tail(10)
# Out:
#                        リリース日     曜日 居住地   年代  性別    退院        date
# 77  2020-03-14T08:00:00.000Z  43904  都外  40代  男性  None  2020-03-14
# 78  2020-03-14T08:00:00.000Z  43904  都内  60代  男性  None  2020-03-14
# 79  2020-03-14T08:00:00.000Z  43904  都内  30代  男性  None  2020-03-14
# 80  2020-03-14T08:00:00.000Z  43904  都内  40代  女性  None  2020-03-14
# 81  2020-03-14T08:00:00.000Z  43904  都外  70代  男性  None  2020-03-14
# 82  2020-03-14T08:00:00.000Z  43904  都内  30代  男性  None  2020-03-14
# 83  2020-03-14T08:00:00.000Z  43904  都内  60代  男性  None  2020-03-14
# 84  2020-03-14T08:00:00.000Z  43904  都内  40代  男性  None  2020-03-14
# 85  2020-03-14T08:00:00.000Z  43904  都内  60代  男性  None  2020-03-14
# 86  2020-03-14T08:00:00.000Z  43904  都内  50代  男性  None  2020-03-14

# %% [markdown]
# ## Total patients' number in Tokyo

# %%
patients_number = len(df_tokyo_data)

print('The number of patients of COVID-19 in Tokyo by 15 March 2020 is',patients_number)
# Out:
# The number of patients of COVID-19 in Tokyo by 15 March 2020 is 87

# %%
# !pip install japanize-matplotlib
# Out:
# Requirement already satisfied: japanize-matplotlib in /Users/kaorumitsumori/opt/anaconda3/lib/python3.7/site-packages (1.0.5)

# %% [markdown]
# ## Pie chart of patients (by age)

# %%
import japanize_matplotlib

x = df_tokyo_data['年代'].value_counts(ascending=True)
label_index = df_tokyo_data['年代'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Pie chart of patients (by gender)

# %%
x = df_tokyo_data['性別'].value_counts(ascending=True)
label_index = df_tokyo_data['性別'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.show()
